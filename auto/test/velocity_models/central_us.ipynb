# %%
import pandas as pd
import numpy as np

# %%
# import central_us.txt to df
# Depth Vp Vs Density
# 0.0 5.0 2.89 2.5
# 1.0 6.1 3.52 2.73

cus_df = pd.read_csv('central_us.txt', sep=' ', header=0)
cus_df
# Out:
#        Depth       Vp      Vs  Density
# 0       0.00   5.0000  2.8900   2.5000
# 1       1.00   6.1000  3.5200   2.7300
# 2      10.00   6.4000  3.7000   2.8200
# 3      20.00   6.7000  3.8700   2.9020
# 4      20.00   6.7000  3.8700   2.9020
# ..       ...      ...     ...      ...
# 132  6168.15  11.2557  3.6633  13.0036
# 133  6218.86  11.2586  3.6653  13.0074
# 134  6269.57  11.2606  3.6667  13.0100
# 135  6320.29  11.2618  3.6675  13.0117
# 136  6371.00  11.2622  3.6678  13.0122
#
# [137 rows x 4 columns]

# %%
# filter df to keep depth and Vp
# Depth(km), Vp(km/s)
# 0.0, 5.0000
# 1.0, 5.0000

filt_cus_df = cus_df[['Depth', 'Vp']]
# change column names to match: Depth(km), Vp(km/s)
filt_cus_df.columns = ['Depth(km)', 'Vp(km/s)']
# save to txt
filt_cus_df.to_csv('central_usp.txt', index=False)
